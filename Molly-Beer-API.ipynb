# %%
# Dependencies
import requests
import json
import pandas as pd
from pprint import pprint

# Google developer API key



url = "https://sandbox-api.brewerydb.com/v2/locations/?key=9a16624ea5903f3a7d7ed5ba7a1d01d9"

# %%
beer_data = requests.get(url).json()
pprint(beer_data)
# Out:
# {'currentPage': 1,
#  'data': [{'brewery': {'createDate': '2012-01-03 02:42:08',
#                        'description': 'The Sierra Nevada Brewing Company was '
#                                       'established in 1980 by homebrewers Ken '
#                                       'Grossman and Paul Camusi. Camusi '
#                                       'retired in 1998 and sold his share in '
#                                       'the company to Grossman.\r\n'
#                                       '\r\n'
#                                       'Located in Chico, California, Sierra '
#                                       'Nevada Brewing is one of the most '
#                                       'popular craft breweries currently '
#                                       'operating in the United States. Its '
#                                       'Pale Ale is world renowned, and the '
#                                       'brewery produces almost 700,000 barrels '
# ...

# %%
pd.DataFrame.from_dict(beer_data)
# Out:
#     currentPage  numberOfPages  totalResults  \
# 0             1              1            42
# 1             1              1            42
# 2             1              1            42
# 3             1              1            42
# 4             1              1            42
# 5             1              1            42
# 6             1              1            42
# 7             1              1            42
# 8             1              1            42
# 9             1              1            42
# 10            1              1            42
# 11            1              1            42
# 12            1              1            42
# 13            1              1            42
# 14            1              1            42
# 15            1              1            42
# 16            1              1            42
# 17            1              1            42
# 18            1              1            42
# 19            1              1            42
# ...

# %%
from pandas.io.json import json_normalize
json_normalize(beer_data)
# Out:
#    currentPage                                               data  \
# 0            1  [{'id': 'aqLvLE', 'name': 'Asheville', 'street...
#
#    numberOfPages   status  totalResults
# 0              1  success            42

# %%
pd.io.json.json_normalize(beer_data[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-398f1bedfd0f> in <module>
# ----> 1 pd.io.json.json_normalize(beer_data[0])
#
# KeyError: 0
